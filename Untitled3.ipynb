# %%
## Metehan Yalçın 05200000571
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,np.pi*2)
ab = 71
bc = 76
w = 571
a = 76*np.arcsin(np.sin(x)/78)
aw = np.cos(x)/(71*np.cos(a))
vc = 76*(np.sin(x)+np.tan(a)*np.cos(x))
vb = 71*(np.cos(x)-np.sin(x))
bx = 71*np.cos(x)
by = 71*np.sin(x)
cy = 0
cx = 76-(np.sin(x)+np.tan(a)*np.cos(x))

plt.title("Konum grafikleri")
plt.plot(x,bx)
plt.plot(x,cx)
plt.xlabel("Açı değerleri")
plt.ylabel("Konumlar")
plt.legend(["C noktasının konumu","B noktasının konumu"])
plt.show()

plt.title("Hız grafikleri")
plt.xlabel("Açı değerleri")
plt.ylabel("Hız değerleri")
plt.plot(x,vb)
plt.plot(x,vc)
plt.legend(["C noktasının hızı","B noktasının hızı"])
plt.show()
